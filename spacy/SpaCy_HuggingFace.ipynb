# %% [markdown]
# <a href="https://colab.research.google.com/github/nickprock/appunti_data_science/blob/master/spacy/SpaCy_HuggingFace.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SpaCy Wrapper per HuggingFace
#
# <br>
#
# ![spacyHF](https://huggingface.co/blog/assets/23_spacy/thumbnail.png)
#
# <br>
#
# In questo notebook c'è spiegato in poche righe come prendere un transformer da Huggingface Hub, wrapparlo in Spacy, condividerlo sull'Hub e utilizzarlo.
#
# ## Downloads
#
# Per prima cosa scarichiamo le librerie:
# * spacy-huggingface-hub
# * spacy-wrap
#
# > spacy-wrap funziona solo con python>=3.8 quindi bisogna fare un check.

# %%
# !python --version
# Out:
# Python 3.10.11

# %%
# !pip install git+https://github.com/KennethEnevoldsen/spacy-wrap
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/KennethEnevoldsen/spacy-wrap
#   Cloning https://github.com/KennethEnevoldsen/spacy-wrap to /tmp/pip-req-build-5wn0lmm3
#   Running command git clone --filter=blob:none --quiet https://github.com/KennethEnevoldsen/spacy-wrap /tmp/pip-req-build-5wn0lmm3
#   Resolved https://github.com/KennethEnevoldsen/spacy-wrap to commit db00ffdeffbef7d0c7e041d1bdcd966f97a9dac1
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting spacy-transformers<1.3.0,>=1.2.1 (from spacy-wrap==1.4.2)
#   Downloading spacy_transformers-1.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.7/190.7 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy-wrap==1.4.2) (3.5.2)
# Requirement already satisfied: thinc<8.2.0,>=8.0.13 in /usr/local/lib/python3.10/dist-packages (from spacy-wrap==1.4.2) (8.1.9)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.2.1->spacy-wrap==1.4.2) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.2.1->spacy-wrap==1.4.2) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.2.1->spacy-wrap==1.4.2) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.2.1->spacy-wrap==1.4.2) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.2.1->spacy-wrap==1.4.2) (3.0.8)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.2.1->spacy-wrap==1.4.2) (1.1.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.2.1->spacy-wrap==1.4.2) (2.4.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.2.1->spacy-wrap==1.4.2) (2.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.2.1->spacy-wrap==1.4.2) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.2.1->spacy-wrap==1.4.2) (0.10.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.2.1->spacy-wrap==1.4.2) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.2.1->spacy-wrap==1.4.2) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.2.1->spacy-wrap==1.4.2) (1.22.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.2.1->spacy-wrap==1.4.2) (2.27.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.2.1->spacy-wrap==1.4.2) (1.10.7)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.2.1->spacy-wrap==1.4.2) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.2.1->spacy-wrap==1.4.2) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.2.1->spacy-wrap==1.4.2) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.2.1->spacy-wrap==1.4.2) (3.3.0)
# Collecting transformers<4.29.0,>=3.4.0 (from spacy-transformers<1.3.0,>=1.2.1->spacy-wrap==1.4.2)
#   Downloading transformers-4.28.1-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 84.8 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from spacy-transformers<1.3.0,>=1.2.1->spacy-wrap==1.4.2) (2.0.1+cu118)
# Collecting spacy-alignments<1.0.0,>=0.7.2 (from spacy-transformers<1.3.0,>=1.2.1->spacy-wrap==1.4.2)
#   Downloading spacy_alignments-0.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 82.3 MB/s eta 0:00:00
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.0.13->spacy-wrap==1.4.2) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.0.13->spacy-wrap==1.4.2) (0.0.4)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.2.1->spacy-wrap==1.4.2) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.2.1->spacy-wrap==1.4.2) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.2.1->spacy-wrap==1.4.2) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.2.1->spacy-wrap==1.4.2) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.2.1->spacy-wrap==1.4.2) (3.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.1->spacy-wrap==1.4.2) (3.12.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.1->spacy-wrap==1.4.2) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.1->spacy-wrap==1.4.2) (3.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.1->spacy-wrap==1.4.2) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.1->spacy-wrap==1.4.2) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.1->spacy-wrap==1.4.2) (16.0.5)
# Collecting huggingface-hub<1.0,>=0.11.0 (from transformers<4.29.0,>=3.4.0->spacy-transformers<1.3.0,>=1.2.1->spacy-wrap==1.4.2)
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 27.4 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers<4.29.0,>=3.4.0->spacy-transformers<1.3.0,>=1.2.1->spacy-wrap==1.4.2) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<4.29.0,>=3.4.0->spacy-transformers<1.3.0,>=1.2.1->spacy-wrap==1.4.2) (2022.10.31)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers<4.29.0,>=3.4.0->spacy-transformers<1.3.0,>=1.2.1->spacy-wrap==1.4.2)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 72.7 MB/s eta 0:00:00
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.2.1->spacy-wrap==1.4.2) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.6.0,>=3.2.1->spacy-wrap==1.4.2) (2.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers<4.29.0,>=3.4.0->spacy-transformers<1.3.0,>=1.2.1->spacy-wrap==1.4.2) (2023.4.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.1->spacy-wrap==1.4.2) (1.3.0)
# Building wheels for collected packages: spacy-wrap
#   Building wheel for spacy-wrap (pyproject.toml) ... done
#   Created wheel for spacy-wrap: filename=spacy_wrap-1.4.2-py3-none-any.whl size=20470 sha256=342ca16547806c19eea0f4cdf39a07131c34be741daca44de903c2afce01887c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ame7xs_7/wheels/57/ac/43/4954ba2efc8dcae8388cc3c19ce495e83e5a4b72c740900ffa
# Successfully built spacy-wrap
# Installing collected packages: tokenizers, spacy-alignments, huggingface-hub, transformers, spacy-transformers, spacy-wrap
# Successfully installed huggingface-hub-0.14.1 spacy-alignments-0.9.0 spacy-transformers-1.2.3 spacy-wrap-1.4.2 tokenizers-0.13.3 transformers-4.28.1

# %%
# !pip install spacy-huggingface-hub
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting spacy-huggingface-hub
#   Downloading spacy_huggingface_hub-0.0.9-py3-none-any.whl (8.3 kB)
# Requirement already satisfied: huggingface-hub>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from spacy-huggingface-hub) (0.14.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from spacy-huggingface-hub) (1.1.1)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy-huggingface-hub) (0.7.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from spacy-huggingface-hub) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.1->spacy-huggingface-hub) (3.12.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.1->spacy-huggingface-hub) (2023.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.1->spacy-huggingface-hub) (2.27.1)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.1->spacy-huggingface-hub) (4.65.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.1->spacy-huggingface-hub) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.1->spacy-huggingface-hub) (23.1)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.8.0,>=0.3.0->spacy-huggingface-hub) (8.1.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.1->spacy-huggingface-hub) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.1->spacy-huggingface-hub) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.1->spacy-huggingface-hub) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.1->spacy-huggingface-hub) (3.4)
# Installing collected packages: spacy-huggingface-hub
# Successfully installed spacy-huggingface-hub-0.0.9

# %% [markdown]
# ## Download del modello dall'Hub
#
# Per questo test userò un modello per la NER in italiano di cui avevo fatto fine-tuning.
#
# * Per prima cosa importiamo le librerie e inizializziamo una pipeline `blank` per l'italiano.
#
# * Secondo step: creiamo il nostro config dove specifichiamo il modello che vogliamo utilizzare e il checkpoint sull'hub.
#
# * Ultimo step: aggiungiamo il nostro *config* alla pipeline con `nlp.add_pipe`
#
# Ora possiamo già usare il modello.
#
# > N.B. il `config` può essere molto più complesso, consiglio la [documentazione ufficiale su spacy wrap](https://spacy.io/universe/project/spacy-wrap)

# %%
import spacy
import spacy_wrap
nlp = spacy.blank("it")

# specify model from the hub
config = {"model": {"name": "nickprock/bert-italian-finetuned-ner"}}

# add it to the pipe
nlp.add_pipe("token_classification_transformer", config=config)

doc = nlp("Ciao, sono Giacomo. Vivo a Milano e lavoro da Armani.")

print(doc.ents)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/380 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/235k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/724k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.90k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# (Giacomo, Milano, Armani)

# %%
nlp.pipe_names
# Out:
# ['token_classification_transformer']

# %% [markdown]
# ## Condividi il modello sull'Hub
#
# Se volessi non utilizzare ogni volta SpaCy Wrap e anzi volessi rendere disponibile il mio lavoro alla community posso condividere semplicemente il mio modello su HuggingFace Hub.
#
# Per prima cosa salvo il modello sul disco.
#
# > N.B. tutto il notebook è creato e usato su colab

# %%
config = nlp.config
bytes_data = nlp.to_bytes()

# %%
nlp.to_disk("/content/sample_data/it_spacy_ner_trf")

# %% [markdown]
# > Ho trovato un piccolo bug (noto alla community) che impediva di fare la build dei modelli correttamente, nella prossima cella la soluzione per aggirarlo.

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %% [markdown]
# per fare la build si può usare la prossima cella, ricordatevi di inserire il parametro `--name` altrimenti SpaCy darà il nome di default, in questo caso `it_pipeline-0.0.0`.

# %%
# !python -m spacy package /content/sample_data/it_spacy_ner_trf /content/sample_data/ --name 'spacy_ner_trf' --build wheel
# Out:
# 2023-05-19 08:50:29.554827: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ℹ Building package artifacts: wheel
# ✔ Including 2 package requirement(s) from meta and config
# spacy-transformers>=1.2.3,<1.3.0, spacy-wrap>=1.4.2,<1.5.0
# ✔ Loaded meta.json from file
# /content/sample_data/it_spacy_ner_trf/meta.json
# ✔ Generated README.md from meta.json
# ✔ Successfully created package directory 'it_spacy_ner_trf-0.0.0'
# /content/sample_data/it_spacy_ner_trf-0.0.0
# running bdist_wheel
# running build
# running build_py
# creating build
# creating build/lib
# creating build/lib/it_spacy_ner_trf
# copying it_spacy_ner_trf/__init__.py -> build/lib/it_spacy_ner_trf
# creating build/lib/it_spacy_ner_trf/it_spacy_ner_trf-0.0.0
# copying it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/tokenizer -> build/lib/it_spacy_ner_trf/it_spacy_ner_trf-0.0.0
# copying it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/README.md -> build/lib/it_spacy_ner_trf/it_spacy_ner_trf-0.0.0
# copying it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/config.cfg -> build/lib/it_spacy_ner_trf/it_spacy_ner_trf-0.0.0
# copying it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/meta.json -> build/lib/it_spacy_ner_trf/it_spacy_ner_trf-0.0.0
# creating build/lib/it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/vocab
# copying it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/vocab/vectors.cfg -> build/lib/it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/vocab
# copying it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/vocab/key2row -> build/lib/it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/vocab
# copying it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/vocab/lookups.bin -> build/lib/it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/vocab
# copying it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/vocab/vectors -> build/lib/it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/vocab
# copying it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/vocab/strings.json -> build/lib/it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/vocab
# creating build/lib/it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/token_classification_transformer
# copying it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/token_classification_transformer/model -> build/lib/it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/token_classification_transformer
# copying it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/token_classification_transformer/cfg -> build/lib/it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/token_classification_transformer
# copying it_spacy_ner_trf/meta.json -> build/lib/it_spacy_ner_trf
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# installing to build/bdist.linux-x86_64/wheel
# running install
# running install_lib
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/wheel
# creating build/bdist.linux-x86_64/wheel/it_spacy_ner_trf
# copying build/lib/it_spacy_ner_trf/__init__.py -> build/bdist.linux-x86_64/wheel/it_spacy_ner_trf
# copying build/lib/it_spacy_ner_trf/meta.json -> build/bdist.linux-x86_64/wheel/it_spacy_ner_trf
# creating build/bdist.linux-x86_64/wheel/it_spacy_ner_trf/it_spacy_ner_trf-0.0.0
# copying build/lib/it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/tokenizer -> build/bdist.linux-x86_64/wheel/it_spacy_ner_trf/it_spacy_ner_trf-0.0.0
# copying build/lib/it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/README.md -> build/bdist.linux-x86_64/wheel/it_spacy_ner_trf/it_spacy_ner_trf-0.0.0
# creating build/bdist.linux-x86_64/wheel/it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/vocab
# copying build/lib/it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/vocab/vectors.cfg -> build/bdist.linux-x86_64/wheel/it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/vocab
# copying build/lib/it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/vocab/key2row -> build/bdist.linux-x86_64/wheel/it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/vocab
# copying build/lib/it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/vocab/lookups.bin -> build/bdist.linux-x86_64/wheel/it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/vocab
# copying build/lib/it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/vocab/vectors -> build/bdist.linux-x86_64/wheel/it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/vocab
# copying build/lib/it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/vocab/strings.json -> build/bdist.linux-x86_64/wheel/it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/vocab
# creating build/bdist.linux-x86_64/wheel/it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/token_classification_transformer
# copying build/lib/it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/token_classification_transformer/model -> build/bdist.linux-x86_64/wheel/it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/token_classification_transformer
# copying build/lib/it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/token_classification_transformer/cfg -> build/bdist.linux-x86_64/wheel/it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/token_classification_transformer
# copying build/lib/it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/config.cfg -> build/bdist.linux-x86_64/wheel/it_spacy_ner_trf/it_spacy_ner_trf-0.0.0
# copying build/lib/it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/meta.json -> build/bdist.linux-x86_64/wheel/it_spacy_ner_trf/it_spacy_ner_trf-0.0.0
# running install_egg_info
# running egg_info
# creating it_spacy_ner_trf.egg-info
# writing it_spacy_ner_trf.egg-info/PKG-INFO
# writing dependency_links to it_spacy_ner_trf.egg-info/dependency_links.txt
# writing entry points to it_spacy_ner_trf.egg-info/entry_points.txt
# writing requirements to it_spacy_ner_trf.egg-info/requires.txt
# writing top-level names to it_spacy_ner_trf.egg-info/top_level.txt
# writing manifest file 'it_spacy_ner_trf.egg-info/SOURCES.txt'
# reading manifest file 'it_spacy_ner_trf.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching 'LICENSE'
# warning: no files found matching 'LICENSES_SOURCES'
# writing manifest file 'it_spacy_ner_trf.egg-info/SOURCES.txt'
# Copying it_spacy_ner_trf.egg-info to build/bdist.linux-x86_64/wheel/it_spacy_ner_trf-0.0.0-py3.10.egg-info
# running install_scripts
# creating build/bdist.linux-x86_64/wheel/it_spacy_ner_trf-0.0.0.dist-info/WHEEL
# creating 'dist/it_spacy_ner_trf-0.0.0-py3-none-any.whl' and adding 'build/bdist.linux-x86_64/wheel' to it
# adding 'it_spacy_ner_trf/__init__.py'
# adding 'it_spacy_ner_trf/meta.json'
# adding 'it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/README.md'
# adding 'it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/config.cfg'
# adding 'it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/meta.json'
# adding 'it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/tokenizer'
# adding 'it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/token_classification_transformer/cfg'
# adding 'it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/token_classification_transformer/model'
# adding 'it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/vocab/key2row'
# adding 'it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/vocab/lookups.bin'
# adding 'it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/vocab/strings.json'
# adding 'it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/vocab/vectors'
# adding 'it_spacy_ner_trf/it_spacy_ner_trf-0.0.0/vocab/vectors.cfg'
# adding 'it_spacy_ner_trf-0.0.0.dist-info/METADATA'
# adding 'it_spacy_ner_trf-0.0.0.dist-info/WHEEL'
# adding 'it_spacy_ner_trf-0.0.0.dist-info/entry_points.txt'
# adding 'it_spacy_ner_trf-0.0.0.dist-info/top_level.txt'
# adding 'it_spacy_ner_trf-0.0.0.dist-info/RECORD'
# removing build/bdist.linux-x86_64/wheel
# ✔ Successfully created binary wheel
# /content/sample_data/it_spacy_ner_trf-0.0.0/dist/it_spacy_ner_trf-0.0.0-py3-none-any.whl

# %% [markdown]
# ### Condividere tramite Spacy HuggingFace Hub
#
# Dopo essersi autentucati col proprio token HuggingFace basa importare dalla libreria la funzione `push` e applicarla al file `.whl` che abbiamo creato con la build.
#
# Ci facciamo stampare l'URL del checkpoint sull'hub per vedere se il processo è andato a buon fine.

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token: Traceback (most recent call last):
#   File "/usr/local/bin/huggingface-cli", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.10/dist-packages/huggingface_hub/commands/huggingface_cli.py", line 45, in main
#     service.run()
#   File "/usr/local/lib/python3.10/dist-packages/huggingface_hub/commands/user.py", line 101, in run
#     login(token=self.args.token, add_to_git_credential=self.args.add_to_git_credential)
#   File "/usr/local/lib/python3.10/dist-packages/huggingface_hub/_login.py", line 92, in login
#     interpreter_login()
#   File "/usr/local/lib/python3.10/dist-packages/huggingface_hub/_login.py", line 142, in interpreter_login
#     token = getpass("Token: ")
#   File "/usr/lib/python3.10/getpass.py", line 77, in unix_getpass
#   File "/usr/lib/python3.10/getpass.py", line 146, in _raw_input
#     line = input.readline()
# KeyboardInterrupt
# ^C

# %%
from spacy_huggingface_hub import push

result = push("/content/sample_data/it_spacy_ner_trf-0.0.0/dist/it_spacy_ner_trf-0.0.0-py3-none-any.whl")
print(result["url"])

# %% [markdown]
# ## Scarica dall'Hub e utilizza direttamente in SpaCy
#
# Tutto pronto ora possiamo utilizzare il nostro transformer in SpaCy come abbiamo sempre fatto con le pipeline di questa libreria.

# %%
# !pip install https://huggingface.co/nickprock/it_spacy_ner_trf/resolve/main/it_spacy_ner_trf-any-py3-none-any.whl

# Using spacy.load().
import spacy
nlp = spacy.load("it_spacy_ner_trf")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting it-spacy-ner-trf==any
#   Downloading https://huggingface.co/nickprock/it_spacy_ner_trf/resolve/main/it_spacy_ner_trf-any-py3-none-any.whl (406.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 406.2/406.2 MB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.1 in /usr/local/lib/python3.10/dist-packages (from it-spacy-ner-trf==any) (3.5.2)
# Requirement already satisfied: spacy-wrap<1.5.0,>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from it-spacy-ner-trf==any) (1.4.2)
# Requirement already satisfied: spacy-transformers<1.3.0,>=1.2.2 in /usr/local/lib/python3.10/dist-packages (from it-spacy-ner-trf==any) (1.2.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.1->it-spacy-ner-trf==any) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.1->it-spacy-ner-trf==any) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.1->it-spacy-ner-trf==any) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.1->it-spacy-ner-trf==any) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.1->it-spacy-ner-trf==any) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.1->it-spacy-ner-trf==any) (8.1.9)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.1->it-spacy-ner-trf==any) (1.1.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.1->it-spacy-ner-trf==any) (2.4.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.1->it-spacy-ner-trf==any) (2.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.1->it-spacy-ner-trf==any) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.1->it-spacy-ner-trf==any) (0.10.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.1->it-spacy-ner-trf==any) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.1->it-spacy-ner-trf==any) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.1->it-spacy-ner-trf==any) (1.22.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.1->it-spacy-ner-trf==any) (2.27.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.1->it-spacy-ner-trf==any) (1.10.7)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.1->it-spacy-ner-trf==any) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.1->it-spacy-ner-trf==any) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.1->it-spacy-ner-trf==any) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.1->it-spacy-ner-trf==any) (3.3.0)
# Requirement already satisfied: transformers<4.29.0,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from spacy-transformers<1.3.0,>=1.2.2->it-spacy-ner-trf==any) (4.28.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from spacy-transformers<1.3.0,>=1.2.2->it-spacy-ner-trf==any) (2.0.1+cu118)
# Requirement already satisfied: spacy-alignments<1.0.0,>=0.7.2 in /usr/local/lib/python3.10/dist-packages (from spacy-transformers<1.3.0,>=1.2.2->it-spacy-ner-trf==any) (0.9.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.1->it-spacy-ner-trf==any) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.1->it-spacy-ner-trf==any) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.1->it-spacy-ner-trf==any) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.1->it-spacy-ner-trf==any) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.1->it-spacy-ner-trf==any) (3.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.1->it-spacy-ner-trf==any) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.1->it-spacy-ner-trf==any) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.2->it-spacy-ner-trf==any) (3.12.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.2->it-spacy-ner-trf==any) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.2->it-spacy-ner-trf==any) (3.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.2->it-spacy-ner-trf==any) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.2->it-spacy-ner-trf==any) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.2->it-spacy-ner-trf==any) (16.0.5)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from transformers<4.29.0,>=3.4.0->spacy-transformers<1.3.0,>=1.2.2->it-spacy-ner-trf==any) (0.14.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers<4.29.0,>=3.4.0->spacy-transformers<1.3.0,>=1.2.2->it-spacy-ner-trf==any) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<4.29.0,>=3.4.0->spacy-transformers<1.3.0,>=1.2.2->it-spacy-ner-trf==any) (2022.10.31)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers<4.29.0,>=3.4.0->spacy-transformers<1.3.0,>=1.2.2->it-spacy-ner-trf==any) (0.13.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.1->it-spacy-ner-trf==any) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.6.0,>=3.5.1->it-spacy-ner-trf==any) (2.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers<4.29.0,>=3.4.0->spacy-transformers<1.3.0,>=1.2.2->it-spacy-ner-trf==any) (2023.4.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.2->it-spacy-ner-trf==any) (1.3.0)
# Installing collected packages: it-spacy-ner-trf
# Successfully installed it-spacy-ner-trf-0.1

# %%
doc = nlp("Domenica andrò a Firenze con Giovanna a guardare la Fiorentina.")

print(doc.ents)
# Out:
# (Firenze, Giovanna, Fiorentina)

# %%
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# Firenze LOC
# Giovanna PER
# Fiorentina LOC
