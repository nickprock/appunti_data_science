# %% [markdown]
# <a href="https://colab.research.google.com/github/nickprock/appunti_data_science/blob/master/semantic-search/DBFR_haystack_qdrant.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install haystack-ai
# !pip install git+https://github.com/deepset-ai/haystack.git@main
# !pip install qdrant-haystack
# !pip install fastembed-haystack
# Out:
# Collecting git+https://github.com/deepset-ai/haystack.git@main
#   Cloning https://github.com/deepset-ai/haystack.git (to revision main) to /tmp/pip-req-build-61ggyyin
#   Running command git clone --filter=blob:none --quiet https://github.com/deepset-ai/haystack.git /tmp/pip-req-build-61ggyyin
#   Resolved https://github.com/deepset-ai/haystack.git to commit 7178aa02532ebc55384b05ee3fd821e73c43133a
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from haystack-ai==2.3.0rc0) (3.1.4)
# Requirement already satisfied: lazy-imports in /usr/local/lib/python3.10/dist-packages (from haystack-ai==2.3.0rc0) (0.3.1)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from haystack-ai==2.3.0rc0) (10.1.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from haystack-ai==2.3.0rc0) (3.3)
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.10/dist-packages (from haystack-ai==2.3.0rc0) (1.25.2)
# Requirement already satisfied: openai>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from haystack-ai==2.3.0rc0) (1.35.10)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from haystack-ai==2.3.0rc0) (2.0.3)
# Requirement already satisfied: posthog in /usr/local/lib/python3.10/dist-packages (from haystack-ai==2.3.0rc0) (3.5.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from haystack-ai==2.3.0rc0) (2.8.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from haystack-ai==2.3.0rc0) (6.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from haystack-ai==2.3.0rc0) (2.31.0)
# Requirement already satisfied: tenacity!=8.4.0 in /usr/local/lib/python3.10/dist-packages (from haystack-ai==2.3.0rc0) (8.4.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from haystack-ai==2.3.0rc0) (4.66.4)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.10/dist-packages (from haystack-ai==2.3.0rc0) (4.12.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.1.0->haystack-ai==2.3.0rc0) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai>=1.1.0->haystack-ai==2.3.0rc0) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.1.0->haystack-ai==2.3.0rc0) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.1.0->haystack-ai==2.3.0rc0) (2.8.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai>=1.1.0->haystack-ai==2.3.0rc0) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->haystack-ai==2.3.0rc0) (2.1.5)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->haystack-ai==2.3.0rc0) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->haystack-ai==2.3.0rc0) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->haystack-ai==2.3.0rc0) (1.16.0)
# Requirement already satisfied: monotonic>=1.5 in /usr/local/lib/python3.10/dist-packages (from posthog->haystack-ai==2.3.0rc0) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from posthog->haystack-ai==2.3.0rc0) (2.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->haystack-ai==2.3.0rc0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->haystack-ai==2.3.0rc0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->haystack-ai==2.3.0rc0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->haystack-ai==2.3.0rc0) (2024.6.2)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai>=1.1.0->haystack-ai==2.3.0rc0) (1.2.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai>=1.1.0->haystack-ai==2.3.0rc0) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.1.0->haystack-ai==2.3.0rc0) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai>=1.1.0->haystack-ai==2.3.0rc0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai>=1.1.0->haystack-ai==2.3.0rc0) (2.20.0)
# Requirement already satisfied: qdrant-haystack in /usr/local/lib/python3.10/dist-packages (4.1.0)
# Requirement already satisfied: haystack-ai>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from qdrant-haystack) (2.3.0rc0)
# Requirement already satisfied: qdrant-client>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from qdrant-haystack) (1.10.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from haystack-ai>=2.0.1->qdrant-haystack) (3.1.4)
# Requirement already satisfied: lazy-imports in /usr/local/lib/python3.10/dist-packages (from haystack-ai>=2.0.1->qdrant-haystack) (0.3.1)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from haystack-ai>=2.0.1->qdrant-haystack) (10.1.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from haystack-ai>=2.0.1->qdrant-haystack) (3.3)
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.10/dist-packages (from haystack-ai>=2.0.1->qdrant-haystack) (1.25.2)
# Requirement already satisfied: openai>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from haystack-ai>=2.0.1->qdrant-haystack) (1.35.10)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from haystack-ai>=2.0.1->qdrant-haystack) (2.0.3)
# Requirement already satisfied: posthog in /usr/local/lib/python3.10/dist-packages (from haystack-ai>=2.0.1->qdrant-haystack) (3.5.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from haystack-ai>=2.0.1->qdrant-haystack) (2.8.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from haystack-ai>=2.0.1->qdrant-haystack) (6.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from haystack-ai>=2.0.1->qdrant-haystack) (2.31.0)
# Requirement already satisfied: tenacity!=8.4.0 in /usr/local/lib/python3.10/dist-packages (from haystack-ai>=2.0.1->qdrant-haystack) (8.4.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from haystack-ai>=2.0.1->qdrant-haystack) (4.66.4)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.10/dist-packages (from haystack-ai>=2.0.1->qdrant-haystack) (4.12.2)
# Requirement already satisfied: grpcio>=1.41.0 in /usr/local/lib/python3.10/dist-packages (from qdrant-client>=1.10.0->qdrant-haystack) (1.64.1)
# Requirement already satisfied: grpcio-tools>=1.41.0 in /usr/local/lib/python3.10/dist-packages (from qdrant-client>=1.10.0->qdrant-haystack) (1.64.1)
# Requirement already satisfied: httpx[http2]>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from qdrant-client>=1.10.0->qdrant-haystack) (0.27.0)
# Requirement already satisfied: portalocker<3.0.0,>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from qdrant-client>=1.10.0->qdrant-haystack) (2.10.0)
# Requirement already satisfied: pydantic>=1.10.8 in /usr/local/lib/python3.10/dist-packages (from qdrant-client>=1.10.0->qdrant-haystack) (2.8.0)
# Requirement already satisfied: urllib3<3,>=1.26.14 in /usr/local/lib/python3.10/dist-packages (from qdrant-client>=1.10.0->qdrant-haystack) (2.0.7)
# Requirement already satisfied: protobuf<6.0dev,>=5.26.1 in /usr/local/lib/python3.10/dist-packages (from grpcio-tools>=1.41.0->qdrant-client>=1.10.0->qdrant-haystack) (5.27.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from grpcio-tools>=1.41.0->qdrant-client>=1.10.0->qdrant-haystack) (67.7.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx[http2]>=0.20.0->qdrant-client>=1.10.0->qdrant-haystack) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx[http2]>=0.20.0->qdrant-client>=1.10.0->qdrant-haystack) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx[http2]>=0.20.0->qdrant-client>=1.10.0->qdrant-haystack) (1.0.5)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx[http2]>=0.20.0->qdrant-client>=1.10.0->qdrant-haystack) (3.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx[http2]>=0.20.0->qdrant-client>=1.10.0->qdrant-haystack) (1.3.1)
# Requirement already satisfied: h2<5,>=3 in /usr/local/lib/python3.10/dist-packages (from httpx[http2]>=0.20.0->qdrant-client>=1.10.0->qdrant-haystack) (4.1.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx[http2]>=0.20.0->qdrant-client>=1.10.0->qdrant-haystack) (0.14.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai>=1.1.0->haystack-ai>=2.0.1->qdrant-haystack) (1.7.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.10.8->qdrant-client>=1.10.0->qdrant-haystack) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.10.8->qdrant-client>=1.10.0->qdrant-haystack) (2.20.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->haystack-ai>=2.0.1->qdrant-haystack) (2.1.5)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->haystack-ai>=2.0.1->qdrant-haystack) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->haystack-ai>=2.0.1->qdrant-haystack) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->haystack-ai>=2.0.1->qdrant-haystack) (1.16.0)
# Requirement already satisfied: monotonic>=1.5 in /usr/local/lib/python3.10/dist-packages (from posthog->haystack-ai>=2.0.1->qdrant-haystack) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from posthog->haystack-ai>=2.0.1->qdrant-haystack) (2.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->haystack-ai>=2.0.1->qdrant-haystack) (3.3.2)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx[http2]>=0.20.0->qdrant-client>=1.10.0->qdrant-haystack) (1.2.1)
# Requirement already satisfied: hyperframe<7,>=6.0 in /usr/local/lib/python3.10/dist-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client>=1.10.0->qdrant-haystack) (6.0.1)
# Requirement already satisfied: hpack<5,>=4.0 in /usr/local/lib/python3.10/dist-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client>=1.10.0->qdrant-haystack) (4.0.0)
# Requirement already satisfied: fastembed-haystack in /usr/local/lib/python3.10/dist-packages (1.2.0)
# Requirement already satisfied: fastembed>=0.2.5 in /usr/local/lib/python3.10/dist-packages (from fastembed-haystack) (0.3.1)
# Requirement already satisfied: haystack-ai>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from fastembed-haystack) (2.3.0rc0)
# Requirement already satisfied: PyStemmer<3.0.0,>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from fastembed>=0.2.5->fastembed-haystack) (2.2.0.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.20 in /usr/local/lib/python3.10/dist-packages (from fastembed>=0.2.5->fastembed-haystack) (0.23.4)
# Requirement already satisfied: loguru<0.8.0,>=0.7.2 in /usr/local/lib/python3.10/dist-packages (from fastembed>=0.2.5->fastembed-haystack) (0.7.2)
# Requirement already satisfied: mmh3<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from fastembed>=0.2.5->fastembed-haystack) (4.1.0)
# Requirement already satisfied: numpy<2,>=1.21 in /usr/local/lib/python3.10/dist-packages (from fastembed>=0.2.5->fastembed-haystack) (1.25.2)
# Requirement already satisfied: onnx<2.0.0,>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from fastembed>=0.2.5->fastembed-haystack) (1.16.1)
# Requirement already satisfied: onnxruntime<2.0.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from fastembed>=0.2.5->fastembed-haystack) (1.18.1)
# Requirement already satisfied: pillow<11.0.0,>=10.3.0 in /usr/local/lib/python3.10/dist-packages (from fastembed>=0.2.5->fastembed-haystack) (10.4.0)
# Requirement already satisfied: requests<3.0,>=2.31 in /usr/local/lib/python3.10/dist-packages (from fastembed>=0.2.5->fastembed-haystack) (2.31.0)
# Requirement already satisfied: snowballstemmer<3.0.0,>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from fastembed>=0.2.5->fastembed-haystack) (2.2.0)
# Requirement already satisfied: tokenizers<1.0,>=0.15 in /usr/local/lib/python3.10/dist-packages (from fastembed>=0.2.5->fastembed-haystack) (0.19.1)
# Requirement already satisfied: tqdm<5.0,>=4.66 in /usr/local/lib/python3.10/dist-packages (from fastembed>=0.2.5->fastembed-haystack) (4.66.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from haystack-ai>=2.0.1->fastembed-haystack) (3.1.4)
# Requirement already satisfied: lazy-imports in /usr/local/lib/python3.10/dist-packages (from haystack-ai>=2.0.1->fastembed-haystack) (0.3.1)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from haystack-ai>=2.0.1->fastembed-haystack) (10.1.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from haystack-ai>=2.0.1->fastembed-haystack) (3.3)
# Requirement already satisfied: openai>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from haystack-ai>=2.0.1->fastembed-haystack) (1.35.10)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from haystack-ai>=2.0.1->fastembed-haystack) (2.0.3)
# Requirement already satisfied: posthog in /usr/local/lib/python3.10/dist-packages (from haystack-ai>=2.0.1->fastembed-haystack) (3.5.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from haystack-ai>=2.0.1->fastembed-haystack) (2.8.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from haystack-ai>=2.0.1->fastembed-haystack) (6.0.1)
# Requirement already satisfied: tenacity!=8.4.0 in /usr/local/lib/python3.10/dist-packages (from haystack-ai>=2.0.1->fastembed-haystack) (8.4.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.10/dist-packages (from haystack-ai>=2.0.1->fastembed-haystack) (4.12.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.20->fastembed>=0.2.5->fastembed-haystack) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.20->fastembed>=0.2.5->fastembed-haystack) (2023.6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.20->fastembed>=0.2.5->fastembed-haystack) (24.1)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from onnx<2.0.0,>=1.15.0->fastembed>=0.2.5->fastembed-haystack) (5.27.2)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.10/dist-packages (from onnxruntime<2.0.0,>=1.17.0->fastembed>=0.2.5->fastembed-haystack) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime<2.0.0,>=1.17.0->fastembed>=0.2.5->fastembed-haystack) (24.3.25)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime<2.0.0,>=1.17.0->fastembed>=0.2.5->fastembed-haystack) (1.12.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.1.0->haystack-ai>=2.0.1->fastembed-haystack) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai>=1.1.0->haystack-ai>=2.0.1->fastembed-haystack) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.1.0->haystack-ai>=2.0.1->fastembed-haystack) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.1.0->haystack-ai>=2.0.1->fastembed-haystack) (2.8.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai>=1.1.0->haystack-ai>=2.0.1->fastembed-haystack) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.31->fastembed>=0.2.5->fastembed-haystack) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.31->fastembed>=0.2.5->fastembed-haystack) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.31->fastembed>=0.2.5->fastembed-haystack) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.31->fastembed>=0.2.5->fastembed-haystack) (2024.6.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->haystack-ai>=2.0.1->fastembed-haystack) (2.1.5)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->haystack-ai>=2.0.1->fastembed-haystack) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->haystack-ai>=2.0.1->fastembed-haystack) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->haystack-ai>=2.0.1->fastembed-haystack) (1.16.0)
# Requirement already satisfied: monotonic>=1.5 in /usr/local/lib/python3.10/dist-packages (from posthog->haystack-ai>=2.0.1->fastembed-haystack) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from posthog->haystack-ai>=2.0.1->fastembed-haystack) (2.2.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai>=1.1.0->haystack-ai>=2.0.1->fastembed-haystack) (1.2.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai>=1.1.0->haystack-ai>=2.0.1->fastembed-haystack) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.1.0->haystack-ai>=2.0.1->fastembed-haystack) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai>=1.1.0->haystack-ai>=2.0.1->fastembed-haystack) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai>=1.1.0->haystack-ai>=2.0.1->fastembed-haystack) (2.20.0)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.10/dist-packages (from coloredlogs->onnxruntime<2.0.0,>=1.17.0->fastembed>=0.2.5->fastembed-haystack) (10.0)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime<2.0.0,>=1.17.0->fastembed>=0.2.5->fastembed-haystack) (1.3.0)

# %%
from haystack import Document, Pipeline
from haystack.components.writers import DocumentWriter
from haystack_integrations.components.retrievers.qdrant import QdrantHybridRetriever, QdrantSparseEmbeddingRetriever, QdrantEmbeddingRetriever
from haystack_integrations.document_stores.qdrant import QdrantDocumentStore
from haystack.document_stores.types import DuplicatePolicy
from haystack_integrations.components.embedders.fastembed import (
	FastembedTextEmbedder,
	FastembedDocumentEmbedder,
	FastembedSparseTextEmbedder,
	FastembedSparseDocumentEmbedder
)
from haystack.components.joiners import DocumentJoiner

document_store = QdrantDocumentStore(
    ":memory:",
    recreate_index=True,
    use_sparse_embeddings=True,
    sparse_idf= True,
    embedding_dim = 384
)

documents = [
    Document(content="My name is Wolfgang and I live in Berlin"),
    Document(content="I saw a black horse running"),
    Document(content="Germany has many big cities"),
    Document(content="fastembed is supported by and maintained by Qdrant."),
]

indexing_pipeline = Pipeline()
indexing_pipeline.add_component("sparse_doc_embedder", FastembedSparseDocumentEmbedder(model="Qdrant/bm42-all-minilm-l6-v2-attentions"))
indexing_pipeline.add_component("dense_doc_embedder", FastembedDocumentEmbedder(model="BAAI/bge-small-en-v1.5"))
indexing_pipeline.add_component("writer", DocumentWriter(document_store=document_store, policy=DuplicatePolicy.OVERWRITE))
indexing_pipeline.connect("sparse_doc_embedder", "dense_doc_embedder")
indexing_pipeline.connect("dense_doc_embedder", "writer")

indexing_pipeline.run({"sparse_doc_embedder": {"documents": documents}})
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# Calculating sparse embeddings: 100%|██████████| 4/4 [00:00<00:00, 65.30it/s]
# Calculating embeddings: 100%|██████████| 4/4 [00:00<00:00, 11.20it/s]
# 100it [00:00, 8645.38it/s]
# {'writer': {'documents_written': 4}}

# %%
querying = Pipeline()
querying.add_component("sparse_text_embedder", FastembedSparseTextEmbedder(model="Qdrant/bm42-all-minilm-l6-v2-attentions"))
querying.add_component("dense_text_embedder", FastembedTextEmbedder(
	model="BAAI/bge-small-en-v1.5", prefix="Represent this sentence for searching relevant passages: ")
	)
querying.add_component("sparse_retriever", QdrantSparseEmbeddingRetriever(document_store=document_store))
querying.add_component("dense_retriever", QdrantEmbeddingRetriever(document_store=document_store))
querying.add_component("joiner", DocumentJoiner("distribution_based_rank_fusion"))

querying.connect("sparse_text_embedder.sparse_embedding", "sparse_retriever.query_sparse_embedding")
querying.connect("dense_text_embedder.embedding", "dense_retriever.query_embedding")
querying.connect("sparse_retriever.documents", "joiner")
querying.connect("dense_retriever.documents", "joiner")

question = "Who supports fastembed?"

results = querying.run(
    {"dense_text_embedder": {"text": question},
     "sparse_text_embedder": {"text": question}}, debug=True
)

print(results["joiner"]["documents"][0])

# Document(id=...,
#  content: 'fastembed is supported by and maintained by Qdrant.',
#  score: 1.0)
# Out:
# Calculating sparse embeddings: 100%|██████████| 1/1 [00:00<00:00, 58.86it/s]
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  7.21it/s]
# Document(id=09074d8d1e7a956dcfa8a0cc75cabad565448c6701e92dc41314eae07af56265, content: 'fastembed is supported by and maintained by Qdrant.', score: 0.7844045030951453)

# %%
results
# Out:
# {'joiner': {'documents': [Document(id=09074d8d1e7a956dcfa8a0cc75cabad565448c6701e92dc41314eae07af56265, content: 'fastembed is supported by and maintained by Qdrant.', score: 0.7844045030951453),
#    Document(id=3cc62890af7a5b7efb4a29d0a1eb394e9ddd142c8c3263d08b1e17599cd4b071, content: 'Germany has many big cities', score: 0.44007128490376024),
#    Document(id=62fad790ad2af927af9432c87330ed2ea5e31332cdec8e9d6235a5105ab0aaf5, content: 'My name is Wolfgang and I live in Berlin', score: 0.41458606113736063),
#    Document(id=f52df56839c8082fb97edec2fd218e16bf431edae30adaf9bc13cdccb46b2883, content: 'I saw a black horse running', score: 0.360938150863734)]}}
